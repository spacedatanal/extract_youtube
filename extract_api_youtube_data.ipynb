# %%
import pandas as pd
import requests
import os
import time
import datetime

from googleapiclient.discovery import build
#path = "../Desktop/Financial/api_tokens.py"
#os.chdir(path)

#from api_tokens import tokens

# %%
API_KEY = "AIzaSyCv0h5jMtJaw1mCEliLuRVBSBJDAjMIVO0"
channel_id = [
    "UCKC77AR_zWXRTE2GOD_2Uag", #Marc Vidal
    "UC71sOOBgRu5UL-opaFVFstw", #CALERO
    "UCVimQoXNCZuEnZRVAbuYMiw", #DIARIO PUBLICO
    "UCBLCvUUCiSqBCEc-TqZ9rGw", #JUAN RALLO
    "UC5HdVtarytnZi4eLogHAfoQ" #VISUAL ECONOMIK
]

youtube = build('youtube', 'v3', developerKey=API_KEY)


id=','.join(channel_id)

# %%
request = youtube.channels().list(
                part='snippet,contentDetails,statistics,topicDetails',id = id)
                #id=','.join(channel_id))
response = request.execute()

# %%
data_user = pd.DataFrame(columns = ["Id","Channel", "Description", "URL", "Views", "Subscribers", "Videos", "topic_details", "related_playlist"])
for item in response["items"]:
    
    Id = item["id"]
    channel = item["snippet"]["title"]
    description = item["snippet"]["description"]
    #country = item["snippet"]["country"]
    customURL = item["snippet"]["customUrl"]
    viewCount = item["statistics"]["viewCount"]
    subscriberCount = item["statistics"]["subscriberCount"]
    videoCount = item["statistics"]["videoCount"]
    topicDetails = item["topicDetails"]["topicCategories"]
    relatedPlaylist = item["contentDetails"]['relatedPlaylists']["uploads"]
    #PENDING TASK TO ADD COUNTRY
    
    data_user = data_user.append(
        {
            "Id": Id,
            "Channel": channel,
            "Description": description,
            #"Country": country,
            "URL":customURL,
            "Views": viewCount,
            "Subscribers": subscriberCount,
            "Videos": videoCount,
            "topic_details": topicDetails,
            "related_playlist": relatedPlaylist
        }, ignore_index = True
    )
    
data_user.index = data_user.Id

# %%
data_user
# Out:
#                                                 Id  \
# Id
# UC71sOOBgRu5UL-opaFVFstw  UC71sOOBgRu5UL-opaFVFstw
# UC5HdVtarytnZi4eLogHAfoQ  UC5HdVtarytnZi4eLogHAfoQ
# UCKC77AR_zWXRTE2GOD_2Uag  UCKC77AR_zWXRTE2GOD_2Uag
# UCVimQoXNCZuEnZRVAbuYMiw  UCVimQoXNCZuEnZRVAbuYMiw
# UCBLCvUUCiSqBCEc-TqZ9rGw  UCBLCvUUCiSqBCEc-TqZ9rGw
#
#                                                      Channel  \
# Id
# UC71sOOBgRu5UL-opaFVFstw  JF CALERO - En un cascarón de nuez
# UC5HdVtarytnZi4eLogHAfoQ                      VisualEconomik
# UCKC77AR_zWXRTE2GOD_2Uag                          Marc Vidal
# UCVimQoXNCZuEnZRVAbuYMiw                      Diario Público
# UCBLCvUUCiSqBCEc-TqZ9rGw                    Juan Ramón Rallo
#
#                                                                 Description  \
# Id
# UC71sOOBgRu5UL-opaFVFstw  JF Calero: Licenciado en CC de la comunicación...
# UC5HdVtarytnZi4eLogHAfoQ  ¡Bienvenidos al canal donde explicamos las his...
# UCKC77AR_zWXRTE2GOD_2Uag  Marc Vidal es un analista económico y divulgad...
# UCVimQoXNCZuEnZRVAbuYMiw  Descubre Público, el diario digital puro más s...
# UCBLCvUUCiSqBCEc-TqZ9rGw                     Laissez faire, laissez passer.
#
#                                                URL      Views Subscribers  \
# Id
# UC71sOOBgRu5UL-opaFVFstw  jfcaleroelcascarondenuez   37969585      343000
# UC5HdVtarytnZi4eLogHAfoQ           @visualeconomik    8896018      238000
# UCKC77AR_zWXRTE2GOD_2Uag            @marcvidalvlog   25702599      334000
# UCVimQoXNCZuEnZRVAbuYMiw                   publico  110043284      494000
# UCBLCvUUCiSqBCEc-TqZ9rGw                 juanrallo   99000124      456000
#
#                          Videos  \
# Id
# UC71sOOBgRu5UL-opaFVFstw    156
# UC5HdVtarytnZi4eLogHAfoQ     36
# UCKC77AR_zWXRTE2GOD_2Uag    302
# UCVimQoXNCZuEnZRVAbuYMiw   7669
# UCBLCvUUCiSqBCEc-TqZ9rGw   1488
#
#                                                               topic_details  \
# Id
# UC71sOOBgRu5UL-opaFVFstw            [https://en.wikipedia.org/wiki/Society]
# UC5HdVtarytnZi4eLogHAfoQ  [https://en.wikipedia.org/wiki/Society, https:...
# UCKC77AR_zWXRTE2GOD_2Uag  [https://en.wikipedia.org/wiki/Society, https:...
# UCVimQoXNCZuEnZRVAbuYMiw  [https://en.wikipedia.org/wiki/Society, https:...
# UCBLCvUUCiSqBCEc-TqZ9rGw            [https://en.wikipedia.org/wiki/Society]
#
#                                   related_playlist
# Id
# UC71sOOBgRu5UL-opaFVFstw  UU71sOOBgRu5UL-opaFVFstw
# UC5HdVtarytnZi4eLogHAfoQ  UU5HdVtarytnZi4eLogHAfoQ
# UCKC77AR_zWXRTE2GOD_2Uag  UUKC77AR_zWXRTE2GOD_2Uag
# UCVimQoXNCZuEnZRVAbuYMiw  UUVimQoXNCZuEnZRVAbuYMiw
# UCBLCvUUCiSqBCEc-TqZ9rGw  UUBLCvUUCiSqBCEc-TqZ9rGw

# %%
def get_video_ids(youtube, playlist_id):
    """
    Get list of video IDs of all videos in the given playlist
    Params:
    
    youtube: the build object from googleapiclient.discovery
    playlist_id: playlist ID of the channel
    
    Returns:
    List of video IDs of all videos in the playlist
    
    """
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

def get_video_details(youtube, video_ids):
    
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    return all_video_info
#video_ids = get_video_ids(youtube, "theeconomist")

# %%
    
def get_comments(youtube, video_ids):
    """ THIS IS TO GET COMMENTS FROM VIDEOS

    """
    more_pages = True
    data_comment = pd.DataFrame(columns = [
                                            "video_id",
                                           "author_id",
                                           "comment_id",
                                           "author_name",
                                           "test_display",
                                           "text_original",
                                           "likes_count",
                                           "date_published",
                                           "date_updated"])
    

    for i in video_ids:
        try:
            request = youtube.commentThreads().list(
                part="Id,snippet",
                videoId=i
            )
            response = request.execute()

            page_token = response.get('nextPageToken')

            for comment in response["items"]:
                basic = comment["snippet"]["topLevelComment"]["snippet"]
                commentId = comment["snippet"]["topLevelComment"]["id"]
                videoId = i
                textDisplay = basic["textDisplay"]
                textOriginal = basic["textOriginal"]
                authorName = basic["authorDisplayName"]
                authorChannelURL = basic["authorChannelId"]["value"]
                likeCount = basic["likeCount"]
                publishedAt = basic["publishedAt"]
                updatedAt = basic["updatedAt"]
                publishedAt = publishedAt.split("T")[0]
                updatedAt = updatedAt.split("T")[0]

                data_comment = data_comment.append(
                    {
                        "video_id":videoId,
                        "author_id":authorChannelURL,
                        "comment_id":commentId,
                        "author_name":authorName,
                        "test_display":textDisplay,
                        "text_original":textOriginal,
                        "likes_count":likeCount,
                        "date_published":publishedAt,
                        "date_updated":updatedAt
                    }, ignore_index = True
                )

            while more_pages:
                if page_token is None:
                    more_pages = False
                else:

                    request = youtube.commentThreads().list(
                        part="Id,snippet",
                        videoId=i,
                        pageToken = page_token
                    )
                    response = request.execute()


                    page_token = response.get('nextPageToken')

                    for comment in response["items"]:
                        basic = comment["snippet"]["topLevelComment"]["snippet"]
                        commentId = comment["snippet"]["topLevelComment"]["id"]
                        videoId = i
                        textDisplay = basic["textDisplay"]
                        textOriginal = basic["textOriginal"]
                        authorName = basic["authorDisplayName"]
                        authorChannelURL = basic["authorChannelId"]["value"]
                        likeCount = basic["likeCount"]
                        publishedAt = basic["publishedAt"]
                        updatedAt = basic["updatedAt"]
                        publishedAt = publishedAt.split("T")[0]
                        updatedAt = updatedAt.split("T")[0]

                        data_comment = data_comment.append(
                            {
                                "video_id":videoId,
                                "author_id":authorChannelURL,
                                "comment_id":commentId,
                                "author_name":authorName,
                                "test_display":textDisplay,
                                "text_original":textOriginal,
                                "likes_count":likeCount,
                                "date_published":publishedAt,
                                "date_updated":updatedAt
                            }, ignore_index = True
                        )   
        except:
            pass
        
        
    
    data_comment.index = data_comment.comment_id
    return data_comment
        
#data_comment = get_comments(youtube, ["JnwPNvkhKmE"])

# %%
video_df = pd.DataFrame()
comments_df = pd.DataFrame()

for c in data_user['Channel'].unique():
    print("Getting video information from channel: " + c)
    playlist_id = data_user.loc[data_user['Channel']== c, 'related_playlist'].iloc[0]
    video_ids = get_video_ids(youtube, playlist_id)
    
    
    # get video data
    video_data = get_video_details(youtube, video_ids)
    # get comment data
    comments_data = get_comments(youtube, video_ids)

    # append video data together and comment data toghether
    video_df = video_df.append(video_data, ignore_index=True)
    comments_df = comments_df.append(comments_data, ignore_index=True)
# Out:
# Getting video information from channel: JF CALERO - En un cascarón de nuez
# Getting video information from channel: VisualEconomik
# Getting video information from channel: Marc Vidal
# Getting video information from channel: Diario Público
# Getting video information from channel: Juan Ramón Rallo

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-207-68b9e3bb367c> in <module>
# ----> 1 max(comments_df.order_by["likes_count"])
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'order_by'

# %%
video_ids

# %%
import pandas as pd
import requests
import os
import time

from googleapiclient.discovery import build
from api_tokens import tokens

from data_extrat_youtube import data_extraction


"""
youtube = build('youtube', 'v3', developerKey=API_KEY)
link_youtube = data_extraction()._request_access(youtube)
param_channel_id = ["UC71sOOBgRu5UL-opaFVFstw"]
data_user = data_extraction()._get_user_id(link_youtube, param_channel_id)
data_playlist = data_extraction()._get_video_ids(link_youtube, data_user)
data_video_ids = data_extraction()._get_video_details(link_youtube, data_playlist)
"""
# Out:
# '\nyoutube = build(\'youtube\', \'v3\', developerKey=API_KEY)\nlink_youtube = data_extraction()._request_access(youtube)\nparam_channel_id = ["UC71sOOBgRu5UL-opaFVFstw"]\ndata_user = data_extraction()._get_user_id(link_youtube, param_channel_id)\ndata_playlist = data_extraction()._get_video_ids(link_youtube, data_user)\ndata_video_ids = data_extraction()._get_video_details(link_youtube, data_playlist)\n'

# %%
API_KEY, = tokens().token_youtube()
#youtube = build('youtube', 'v3', developerKey=API_KEY)
#link_youtube = data_extraction._request_access(API_KEY)
API_KEY
# Out:
# 'AIzaSyCv0h5jMtJaw1mCEliLuRVBSBJDAjMIVO0'

# %%
class data_extraction():
    
    def __init__(self, API_KEY):
        self.API_KEY = API_KEY
        self._link_youtube = self._request_access()

    def _request_access(self):
        youtube = build('youtube', 'v3', developerKey=self.API_KEY)
        return youtube
    
    def _get_user_id(self, channel_id):
        
        youtube = self._request_access()
        request = youtube.channels().list(
                part='snippet,contentDetails,statistics,topicDetails',
                id=','.join(channel_id))
        response = request.execute() 

        data_user = pd.DataFrame(columns = ["Id","Channel", "Description", "URL", "Views", "Subscribers", "Videos", "topic_details", "related_playlist"])
        for item in response["items"]:
            
            Id = item["id"]
            channel = item["snippet"]["title"]
            description = item["snippet"]["description"]
            #country = item["snippet"]["country"]
            customURL = item["snippet"]["customUrl"]
            viewCount = item["statistics"]["viewCount"]
            subscriberCount = item["statistics"]["subscriberCount"]
            videoCount = item["statistics"]["videoCount"]
            topicDetails = item["topicDetails"]["topicCategories"]
            relatedPlaylist = item["contentDetails"]['relatedPlaylists']["uploads"]
            #PENDING TASK TO ADD COUNTRY
            
            data_user = data_user.append(
                {
                    "Id": Id,
                    "Channel": channel,
                    "Description": description,
                    #"Country": country,
                    "URL":customURL,
                    "Views": viewCount,
                    "Subscribers": subscriberCount,
                    "Videos": videoCount,
                    "topic_details": topicDetails,
                    "related_playlist": relatedPlaylist
                }, ignore_index = True
            )
            
        data_user.index = data_user.Id
        return data_user
    
    def _get_video_ids(self, playlist_id, max_days = 7):
        """
        Get list of video IDs of all videos in the given playlist
        Params:
        
        youtube: the build object from googleapiclient.discovery
        playlist_id: playlist ID of the channel
        
        Returns:
        List of video IDs of all videos in the playlist
        
        """
        youtube = self._request_access()
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 20)
        response = request.execute()
        
        video_ids = []
        _limit = False
        
        for i in range(len(response['items'])):
            #video_ids.append(response['items'][i]['contentDetails']['videoId'])
            _video_data = response['items'][i]["contentDetails"]["videoPublishedAt"].split("T")[0]
            if max_days == "Full":
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            else:
                dto = datetime.datetime.strptime(_video_data, '%Y-%m-%d').date()
                delta = datetime.date.today() - dto
                val = delta.days
                if val > max_days:
                    _limit = True
                else:
                   video_ids.append(response['items'][i]['contentDetails']['videoId']) 

        next_page_token = response.get('nextPageToken')
        more_pages = True

        while more_pages & (_limit==False):
            if next_page_token is None:
                more_pages = False
            else:
                youtube = self._request_access()
                request = youtube.playlistItems().list(
                            part='contentDetails',
                            playlistId = playlist_id,
                            maxResults = 50,
                            pageToken = next_page_token)
                response = request.execute()

                for i in range(len(response['items'])):
                    _video_data = response['items'][i]["contentDetails"]["videoPublishedAt"].split("T")[0]
                    if max_days == "Full":
                        video_ids.append(response['items'][i]['contentDetails']['videoId'])
                    else:
                        dto = datetime.datetime.strptime(_video_data, '%Y-%m-%d').date()
                        delta = datetime.date.today() - dto
                        val = delta.days
                        if val > max_days:
                            _limit = True
                        else:
                           video_ids.append(response['items'][i]['contentDetails']['videoId']) 

                next_page_token = response.get('nextPageToken')
                
        return video_ids
    
    def _get_video_details(self, video_ids):
        
        all_video_info = []
        
        for i in range(0, len(video_ids)):
            youtube = self._request_access()
            request = youtube.videos().list(
                part="snippet,contentDetails,statistics",
                id=','.join(video_ids[i:i+50])
            )
            response = request.execute() 

            for video in response['items']:
                stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                                'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                                'contentDetails': ['duration', 'definition', 'caption']
                                }
                video_info = {}
                video_info['video_id'] = video['id']

                for k in stats_to_keep.keys():
                    for v in stats_to_keep[k]:
                        try:
                            video_info[v] = video[k][v]
                        except:
                            video_info[v] = None

                all_video_info.append(video_info)
        return all_video_info
    
    def _structure_comments(self, df, i, comment):
        
        basic = comment["snippet"]["topLevelComment"]["snippet"]
        commentId = comment["snippet"]["topLevelComment"]["id"]
        videoId = i
        textDisplay = basic["textDisplay"]
        textOriginal = basic["textOriginal"]
        authorName = basic["authorDisplayName"]
        authorChannelURL = basic["authorChannelId"]["value"]
        likeCount = basic["likeCount"]
        publishedAt = basic["publishedAt"]
        updatedAt = basic["updatedAt"]
        publishedAt = publishedAt.split("T")[0]
        updatedAt = updatedAt.split("T")[0]

        data_comment = df.append(
            {
                "video_id":videoId,
                "author_id":authorChannelURL,
                "comment_id":commentId,
                "author_name":authorName,
                "test_display":textDisplay,
                "text_original":textOriginal,
                "likes_count":likeCount,
                "date_published":publishedAt,
                "date_updated":updatedAt
            }, ignore_index = True
        )
        
        return data_comment
    
    def _get_comments(self, video_ids):
        """ THIS IS TO GET COMMENTS FROM VIDEOS

        """
        more_pages = True
        data_comment = pd.DataFrame(columns = [
                                                "video_id",
                                               "author_id",
                                               "comment_id",
                                               "author_name",
                                               "test_display",
                                               "text_original",
                                               "likes_count",
                                               "date_published",
                                               "date_updated"])


        for i in video_ids:
            
            try:
                youtube = self._request_access()
                request = youtube.commentThreads().list(
                    part="Id,snippet",
                    videoId=i
                )
                response = request.execute()
                #print(i["title"], response)
                page_token = response.get('nextPageToken')

                for comment in response["items"]:

                    data_comment = self._structure_comments(data_comment, i, comment)

                while more_pages:
                    if page_token is None:
                        more_pages = False
                    else:
                        youtube = self._request_access()
                        request = youtube.commentThreads().list(
                            part="Id,snippet",
                            videoId=i,
                            pageToken = page_token
                        )
                        response = request.execute()


                        page_token = response.get('nextPageToken')

                        for comment in response["items"]:
                            data_comment = self._structure_comments(data_comment, i, comment)
            except:
                pass



        data_comment.index = data_comment.comment_id
        return data_comment

# %%
param_channel_id = ["UCHd62-u_v4DvJ8TCFtpi4GA" #The Washington Post
                    , "UCWNpXitY8eJ-ku6M-v25MKw" # Joe Biden
                    , "UCqnbDFdCpuN8CMEg0VuEBqA" # NY Times
                   ]

API_KEY, = tokens().token_youtube()
_initiation = data_extraction(API_KEY)
data_user = _initiation._get_user_id(param_channel_id)
for c in data_user["Channel"].unique():
    playlist_id = data_user.loc[data_user['Channel']== c, 'related_playlist'].iloc[0]
    data_playlist = _initiation._get_video_ids(playlist_id, max_days = 240)
    data_video_ids = _initiation._get_video_details(data_playlist)
    data_comments = _initiation._get_comments(data_playlist)

# %%
data_video_ids
video_ids = pd.DataFrame(columns = ["video_id",
                                    "channeltitle",
                                    "title",
                                    "description",
                                    "tags",
                                    "publishedAt", 
                                    "viewCount", 
                                    "likeCount", 
                                    "favouriteCount", 
                                    "commentCount",
                                   "duration"])

for video in data_video_ids:
    videoId = video["video_id"]
    channelTitle = video["channelTitle"]
    title = video["title"]
    description = video["description"]
    tags = video["tags"]
    publishedAt = video["publishedAt"].split(" ")[0]
    viewCount = video["viewCount"]
    likeCount = video["likeCount"]
    favouriteCount = video["favouriteCount"]
    commentCount = video["commentCount"]
    duration = video["duration"].split("T")[0]
    
    video_ids = video_ids.append(
        {
            "video_id": videoId,
            "channeltitle": channelTitle,
            "title": title,
            "description": description,
            "tags": tags,
            "publishedAt": publishedAt,
            "viewCount": viewCount,
            "likeCount":likeCount ,
            "favouriteCount": favouriteCount,
            "commentCount":commentCount ,
            "duration": duration
        }, ignore_index = True
    )

# %%
video_ids.to_csv("videos_eeuu.csv")

# %%
data_video_ids
# Out:
# [{'video_id': 'ZoEaG4pmOrs',
#   'channelTitle': 'Joe Biden',
#   'title': 'Maryland Grassroots Event with President Joe Biden',
#   'description': 'In Maryland to discuss what’s at stake in this election and how we will continue to deliver for the American people. Tune in now.\n\n\nFollow Joe!\nJoe’s Twitter: https://twitter.com/joebiden\nJoe’s Facebook: https://www.facebook.com/joebiden\nJoe’s Instagram: https://www.instagram.com/joebiden\n\n#JoeBiden',
#   'tags': ['joe biden',
#    'biden',
#    'joe biden ad',
#    'biden ad',
#    'joe biden ad 2020',
#    'joe biden campaign video',
#    'joe biden campaign ad',
#    'joe biden youtube ad',
#    'biden ads',
#    'joe biden speech',
#    'biden trump',
#    '2020 elections',
#    'politics'],
#   'publishedAt': '2022-08-26T00:14:49Z',
#   'viewCount': '11035',
#   'likeCount': '810',
#   'favouriteCount': None,
#   'commentCount': '350',
#   'duration': 'PT51M40S',
#   'definition': 'hd',
#   'caption': 'false'}]

# %%
video_ids
# Out:
# ['P3C-l_7iX5M',
#  'ANqtzE99e70',
#  'qNRstSRtTPQ',
#  '2Bvkwwzblzk',
#  'Ef9DgIHj5TM',
#  'u1roG7_yveM',
#  'AtG_O2gzJW0',
#  'b0lzohOl8Y0']

# %%
playlist_id
# Out:
# 'UU71sOOBgRu5UL-opaFVFstw'
